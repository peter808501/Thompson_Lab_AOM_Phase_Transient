# %%
import numpy as np
import matplotlib.pyplot as plt

CW_angle_List = np.load("CW_angle_list.npy")

print(CW_angle_List)


CCW_angle_list = np.load("CCW_angle_list.npy")
print(CCW_angle_list)
# Out:
# [0.         0.0064686  0.01002174 0.01730654 0.02368713 0.02880791
#  0.03525815 0.04217623 0.05058224 0.05686039 0.06373496]
# [0.         0.00334558 0.01023568 0.01669266 0.02023166 0.03231878
#  0.03938783 0.04703459 0.05684489 0.07179629 0.08557422]

# %%
CW0 = np.load("CW0_demod.npz")
amp0_exp = CW0['amplitude']
phase0_exp = CW0['phase']
t0_exp = CW0['t']

plt.plot(t0_exp, phase0_exp)
plt.plot(t0_exp, amp0_exp)
plt.xlim(4e-6, 6e-6)
# Out:
# (4e-06, 6e-06)
